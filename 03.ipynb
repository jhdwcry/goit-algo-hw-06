# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
users = ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
G.add_nodes_from(users)

edges_with_weights = [
    ('Alice', 'Bob', 1),
    ('Bob', 'Charlie', 2),
    ('Charlie', 'David', 1),
    ('David', 'Eve', 2),
    ('Eve', 'Alice', 3),
    ('Alice', 'Charlie', 4)
]
G.add_weighted_edges_from(edges_with_weights)

pos = nx.spring_layout(G)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, edge_color='gray', font_size=15)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.title("Twitter Social Network with Weights")
plt.show()

def dijkstra_all_pairs(graph):
    shortest_paths = {}
    for node in graph.nodes():
        shortest_paths[node] = nx.single_source_dijkstra_path(graph, node)
    return shortest_paths

shortest_paths = dijkstra_all_pairs(G)

for start_node, paths in shortest_paths.items():
    print(f"Shortest paths from {start_node}:")
    for end_node, path in paths.items():
        print(f"  To {end_node}: {path}")
# Out:
# Shortest paths from Alice:
#   To Alice: ['Alice']
#   To Bob: ['Alice', 'Bob']
#   To Charlie: ['Alice', 'Bob', 'Charlie']
#   To David: ['Alice', 'Bob', 'Charlie', 'David']
#   To Eve: ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
# Shortest paths from Bob:
#   To Bob: ['Bob']
#   To Charlie: ['Bob', 'Charlie']
#   To David: ['Bob', 'Charlie', 'David']
#   To Eve: ['Bob', 'Charlie', 'David', 'Eve']
#   To Alice: ['Bob', 'Charlie', 'David', 'Eve', 'Alice']
# Shortest paths from Charlie:
#   To Charlie: ['Charlie']
#   To David: ['Charlie', 'David']
#   To Eve: ['Charlie', 'David', 'Eve']
#   To Alice: ['Charlie', 'David', 'Eve', 'Alice']
#   To Bob: ['Charlie', 'David', 'Eve', 'Alice', 'Bob']
# Shortest paths from David:
#   To David: ['David']
#   To Eve: ['David', 'Eve']
#   To Alice: ['David', 'Eve', 'Alice']
#   To Bob: ['David', 'Eve', 'Alice', 'Bob']
#   To Charlie: ['David', 'Eve', 'Alice', 'Bob', 'Charlie']
# Shortest paths from Eve:
#   To Eve: ['Eve']
#   To Alice: ['Eve', 'Alice']
#   To Bob: ['Eve', 'Alice', 'Bob']
#   To Charlie: ['Eve', 'Alice', 'Bob', 'Charlie']
#   To David: ['Eve', 'Alice', 'Bob', 'Charlie', 'David']
